# %% [markdown]
# # CHART FROM DATAFRAME
# ---

# %% [markdown]
# ## Creating Chart From DataFrame

# %% [markdown]
# As you remember, a Pandas DataFrame is a two-dimensional data structure that resembles a table with rows and columns. It is a fundamental component in data manipulation and analysis using Python. A DataFrame can contain multiple data sets.
#
# When creating a chart, you can present data from all columns, or you can select a column or set of columns and present data from selected columns on the chart.

# %% [markdown]
# Imagine that the data includes average Euro and Dollar exchange rates for the last four days. To create a line charts, just create a chart as you would for a single data series.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
currency = {'USD':[3.98,3.97,4.09,4.02],'EUR':[4.28,4.47,4.41,4.41]}
df = pd.DataFrame(data = currency)
df.index = [1,2,3,4]
df
# Out:
#     USD   EUR
# 1  3.98  4.28
# 2  3.97  4.47
# 3  4.09  4.41
# 4  4.02  4.41

# %%
df.plot(title='Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# If you would like to chart changes in the exchange rate of only one currency, enter the name of the column that contains the values for that currency.

# %%
df['USD'].plot(title='USD Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'USD Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# ### Tasks

# %% [markdown]
# Create a chart for the Euro currency.

# %%
df['EUR'].plot(title='EUR Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'EUR Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# The exchange rates in the last 4 days for Pound Sterling (GBP) were: 5.01, 4.87, 4.98, 5.09. Add the values of the new currency to your dataset. Create a chart with EUR and GBP (excluding USD) exchange rates.

# %%
currency1 = {'EUR':[4.28,4.47,4.41,4.41],"GBP":[5.01,4.87,4.89,5.09]}
df = pd.DataFrame(data = currency1)
df.index = [1,2,3,4]
df.plot(title='Currency Rates', xlabel='Days', ylabel='Exchange Rates')
# Out:
# <Axes: title={'center': 'Currency Rates'}, xlabel='Days', ylabel='Exchange Rates'>

# %% [markdown]
# ## Creating Subplots

# %% [markdown]
# Each series in a DataFrame can be also plotted on a different axis with the using of subplots. The 'layout' parameter specifies the number of rows and columns in which the charts will be placed.

# %%
df.plot(subplots=True, title='Currency Rates', xlabel='Days', ylabel='Exchange Rates', layout=(2,1))
# Out:
# array([[<Axes: xlabel='Days', ylabel='Exchange Rates'>],
#        [<Axes: xlabel='Days', ylabel='Exchange Rates'>]], dtype=object)

# %% [markdown]
# ### Tasks

# %% [markdown]
# Add a grid to your charts. Search the Internet to find out what parameter you should use to add a grid.

# %%
df.plot(subplots=True, title='Currency Rates', xlabel='Days', ylabel='Exchange Rates', layout=(2,1), grid=True)
# Out:
# array([[<Axes: xlabel='Days', ylabel='Exchange Rates'>],
#        [<Axes: xlabel='Days', ylabel='Exchange Rates'>]], dtype=object)

# %% [markdown]
# The travel agency organizes holiday trips to London, Paris and Barcelona. The table below shows the number of tourists who visited the given cities in July and August. Plot the data on a horizontal(!) bar chart. Do not forget to add a chart title and axis descriptions.
#
# Destination | Toursits in July | Tourists in August
# ------------|:----------------:|:-----------------:
# Paris       | 370              | 409
# London      | 202              | 315
# Barcelona   | 584              | 712

# %%
data = {'Paris':[370,409],'London':[202,315],'Barcelona':[584,712]}
df = pd.DataFrame(data)
df.index = ["July", "August"]
df.plot(kind="barh", title="Number of tourist visiting the city ", ylabel="Month",xlabel="Tourist")
# Out:
# <Axes: title={'center': 'Number of tourist visiting the city '}, xlabel='Tourist', ylabel='Month'>

# %% [markdown]
# Using the continents.csv file, create separate bar charts to present information about the population and area of the continents.

# %%
data ={"Europe":[10000000,745173774],
       "Asia":[44614000,4694576167],
       "North America":[24230000,595783465],
       "Oceania":[24230000,595783465],
       "Africa":[30365000,1393676444],      
}
DataFrame=pd.DataFrame(data)
DataFrame.index=["Area","Population"]
DataFrame.plot(kind="bar", subplots=True, layout=(5,2), logy=True, figsize=(20,20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jj/Desktop/Semest 6/Processing and visualizing data/Data Visualisation-zajecia3/dataframe-chart.ipynb Komórka 24 line 9
#       <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/dataframe-chart.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> DataFrame=pd.DataFrame(data)
#       <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/dataframe-chart.ipynb#X32sZmlsZQ%3D%3D?line=7'>8</a> DataFrame.index=["Area","Population"]
# ----> <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/dataframe-chart.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> DataFrame.plot(subplots=True, title='Continents', xlabel='Days', ylabel='Exchange Rates', layout=(2,1), grid=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:500, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
#     499     self._compute_plot_data()
# --> 500     fig = self.fig
#     501     self._make_plot(fig)
#     502     self._add_table()
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:555, in MPLPlot.fig(self)
#     552 @final
#     553 @cache_readonly
#     554 def fig(self) -> Figure:
# --> 555     return self._axes_and_fig[1]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:570, in MPLPlot._axes_and_fig(self)
#     566 if self.subplots:
#     567     naxes = (
#     568         self.nseries if isinstance(self.subplots, bool) else len(self.subplots)
#     569     )
# --> 570     fig, axes = create_subplots(
#     571         naxes=naxes,
#     572         sharex=self.sharex,
#     573         sharey=self.sharey,
#     574         figsize=self.figsize,
#     575         ax=self.ax,
#     576         layout=self.layout,
#     577         layout_type=self._layout_type,
#     578     )
#     579 elif self.ax is None:
#     580     fig = self.plt.figure(figsize=self.figsize)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/tools.py:276, in create_subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#     268         warnings.warn(
#     269             "To output multiple subplots, the figure containing "
#     270             "the passed axes is being cleared.",
#     271             UserWarning,
#     272             stacklevel=find_stack_level(),
#     273         )
#     274         fig.clear()
# --> 276 nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#     277 nplots = nrows * ncols
#     279 # Create empty object array to hold all axes.  It's easiest to make it 1-d
#     280 # so we can just append subplots upon creation, and then
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_matplotlib/tools.py:112, in _get_layout(nplots, layout, layout_type)
#     109         raise ValueError(msg)
#     111     if nrows * ncols < nplots:
# --> 112         raise ValueError(
#     113             f"Layout of {nrows}x{ncols} must be larger than required size {nplots}"
#     114         )
#     116     return layout
#     118 if layout_type == "single":
#
# ValueError: Layout of 2x1 must be larger than required size 5

# %% [markdown]
# Europe,10000000,745173774
# Asia,44614000,4694576167
# North America,24230000,595783465
# Oceania,8510926,44491724
# Africa,30365000,1393676444
