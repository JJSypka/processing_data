# %%
import pandas as pd 
import matplotlib as mpl

# %% [markdown]
#  The list below contains the tennis players who have won the most Grand Slam tournaments.
#
#     Player         | Titles
#     ---------------|-------
#     Novak Djokovic | 24
#     Rafael Nadal   | 22
#     Roger Federer  | 20
#     Pete Sampras   | 14

# %% [markdown]
# Create a new notebook and then a chart presenting the data from the table. Remember to include the title and description of the chart axis.

# %%
titles = [24,22,20,14]
DataFrame= pd.DataFrame(titles)
DataFrame.index= ['Novak Djokovic', 'Rafael Nadal','Roger Federe', 'Pete Sampres']
DataFrame.plot(kind= "bar", title="Tenis players with the most Grand Slams", xlabel="Name of a player", ylabel="Number of GrandSlams")
# Out:
# <Axes: >
