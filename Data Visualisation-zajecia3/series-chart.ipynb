# %% [markdown]
# # CHART FROM SERIES
# ---

# %% [markdown]
# ## Creating Chart From Data Series
#
# To create a chart, first you have to import the necessary librares:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Now, you need data to plot a chart. The data below shows the number of people who watched the latest movie in the cinema, from Monday to Friday.

# %%
data = [410,395,515,457,490]
ds = pd.Series(data)
ds
# Out:
# 0    410
# 1    395
# 2    515
# 3    457
# 4    490
# dtype: int64

# %% [markdown]
# To create a plot, use the plot() function:\
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html

# %%
ds.plot()
# Out:
# <Axes: >

# %% [markdown]
# To add labels on the X axis, add an index to the dataset you created.

# %%
ds.index = ['Monday','Tuesday','Wednesday','Thursday','Friday']
ds
# Out:
# Monday       410
# Tuesday      395
# Wednesday    515
# Thursday     457
# Friday       490
# dtype: int64

# %%
ds.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Tasks

# %% [markdown]
# On Saturday and Sunday, the movie was watched by 610 and 692 people, respectively. Complete the chart with this data.

# %%
dane = [410,395,515,457,490,610,692]
dataSeries = pd.Series(dane)
dataSeries.index = ['Monday','Tuesday','Wednesday','Thursday','Friday', 'Saturday','Sunday']
dataSeries = pd.Series(dane)
dataSeries.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Adding Chart Title and Axis Description

# %% [markdown]
# Each chart should have a title. To add it, use the plot() function attribute.

# %%
ds.plot(title="People Watched a Movie")
# Out:
# <Axes: title={'center': 'People Watched a Movie'}>

# %% [markdown]
# To add a description of the X-axis of the plot, use the appropriate attribute of the plot() function.

# %%
ds.plot(title="People Watched a Movie", xlabel='Days of Week')
# Out:
# <Axes: title={'center': 'People Watched a Movie'}, xlabel='Days of Week'>

# %% [markdown]
# ### Tasks
#
# Now try to add the correct description of the Y axis.

# %%
ds.plot(title="People Watched a Movie", xlabel='Days of Week', ylabel="Number of people")
# Out:
# <Axes: title={'center': 'People Watched a Movie'}, xlabel='Days of Week', ylabel='Number of people'>

# %% [markdown]
# ## Changing Chart Type
#
# By default, a line chart is created. To change the type of chart to a bar, use the kind attribute.

# %%
ds.plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# If you would like to create a pie chart, apply the value 'pie' to the kind attribute.

# %%
ds.plot(kind='pie', autopct='%1.0f%%')
# Out:
# <Axes: >

# %% [markdown]
# ### Tasks
#
# Complete the above bar chart by adding its title and axis descriptions.

# %%
ds.plot(title= "Percentage of people watching Tv during week",kind='pie', autopct='%1.0f%%', xlabel="Day", ylabel = "Percentage of people")
# Out:
# <Axes: title={'center': 'Percentage of people watching Tv during week'}, ylabel='Percentage of people'>

# %% [markdown]
# The calorie content of a student's meals is as follows: breakfast 650 calories, lunch 420 calories and dinner 890 calories. Present the data in a bar chart. Add a chart title, axis descriptions, and correct x-axis labels.

# %%
studentMeals=[650,420,890]
studentMealsDF=pd.DataFrame(studentMeals)
studentMealsDF.index = ['Breakfest', "Launch", "Dinner"]
studentMealsDF.plot(title= "Number of calories eaten by student during the day",kind='bar', xlabel="Calories", ylabel = "Meal")
# Out:
# <Axes: title={'center': 'Number of calories eaten by student during the day'}, xlabel='Calories', ylabel='Meal'>

# %% [markdown]
# The company's department employs 37 people, 14 of which are women. Create a pie chart showing the percentage of men and women employed in this department.

# %%
labels = 'Man', 'Woman'
sizes = [23,14]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jj/Desktop/Semest 6/Processing and visualizing data/Data Visualisation-zajecia3/series-chart.ipynb Komórka 30 line 4
#       <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/series-chart.ipynb#X41sZmlsZQ%3D%3D?line=1'>2</a> Workers = pd.DataFrame(companyWorkers)
#       <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/series-chart.ipynb#X41sZmlsZQ%3D%3D?line=2'>3</a> Workers.index=["Woman"," Man"]
# ----> <a href='vscode-notebook-cell:/Users/jj/Desktop/Semest%206/Processing%20and%20visualizing%20data/Data%20Visualisation-zajecia3/series-chart.ipynb#X41sZmlsZQ%3D%3D?line=3'>4</a> Workers.plot(kind='pie', autopct='%1.0f%%')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/plotting/_core.py:981, in PlotAccessor.__call__(self, *args, **kwargs)
#     979 if isinstance(data, ABCDataFrame):
#     980     if y is None and kwargs.get("subplots") is False:
# --> 981         raise ValueError(
#     982             f"{kind} requires either y column or 'subplots=True'"
#     983         )
#     984     if y is not None:
#     985         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'
